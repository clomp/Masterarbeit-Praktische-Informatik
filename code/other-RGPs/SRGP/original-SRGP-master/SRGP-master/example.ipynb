# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import GPy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from RECC import REC
from optim import Adam
from mix import genData

# %% [markdown]
# # generate some GP data

# %%
# generate training and testing data
np.random.seed(1234) 
X_train, X_test, Y_train, F_test, Y_test = genData(2000, D=1,lengthscale=[0.1], sig2_0=1.**2, sig2_noise=0.15**2)

# %%
plt.figure(figsize=(13,4))
plt.plot(X_test, F_test, label='true');
plt.plot(X_train,Y_train, 'r.', label='data');
plt.legend();

# %% [markdown]
# # intitial values

# %%
# hyperparameters
sig_0_init = 1.
ls_init = [1.]
sig_noise_init = 1.0

# inducing inputs
M = 15
RR = np.linspace(-1,1,M)[:,None] 
α = 0.0001

# define kernel
kern = GPy.kern.RBF(input_dim = 1, variance=sig_0_init, lengthscale=ls_init, ARD=True)

# %% [markdown]
# # batch sparse model with GPy

# %%
# define sparse mdoel
mod = GPy.models.SparseGPRegression(X_train, Y_train, kern.copy(), Z=RR.copy() )
# mod.inference_method = GPy.inference.latent_function_inference.VarDTC()
mod.inference_method = GPy.inference.latent_function_inference.PEP(α)
mod.Gaussian_noise = sig_0_init
mod.optimize(messages=False);

# %%
mod
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse_gp<br>
# <b>Objective</b>: -645.6885655745864<br>
# <b>Number of Parameters</b>: 18<br>
# <b>Number of Optimization Parameters</b>: 18<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sparse_gp.             </b></th><th><b>               value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  inducing inputs        </td><td class=tg-right>             (15, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right> 0.10223105487118453</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right> 0.10464630749600498</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.026561841508342725</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
m1, v1 = mod.predict(X_test)

# %% [markdown]
# # recursive sparse model SRGP

# %%
sizeMiniBatch = 100
nEpochs = 100

# %%
# initial params
θ = {'σ0': sig_0_init, 'ls': np.ones(1)*ls_init, 'σn': sig_noise_init, 'R': RR.copy()}

# define optimizer for parameters
θopt_σ0 = Adam(0.01, (1,) ) 
θopt_σn = Adam(0.01, (1,) ) 
θopt_ls = Adam(0.01, (1,) ) 
θopt_R = Adam(0.001, RR.shape )   
θopt = {'σ0': θopt_σ0, 'ls': θopt_ls, 'σn': θopt_σn, 'R': θopt_R}

# %%
np.random.seed(123) # seed for permutation of the data
modSRGP = REC(X_train, Y_train, kern.copy(), nEpochs, sizeMiniBatch, θ, θopt, α=α, 
           Xtest=X_test, Ftest=F_test[:,0], Ytest=Y_test[:,0] ) # only for performance testing

modSRGP.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18696\3404597139.py in <module>
#       3            Xtest=X_test, Ftest=F_test[:,0], Ytest=Y_test[:,0] ) # only for performance testing
#       4
# ----> 5 modSRGP.run()
#
# ~\Documents\SRGP-master\SRGP-master\RECC.py in run(self)
#     180
#     181             self.reset_perm()
# --> 182             self.reset_epoch()
#     183
#     184             for i_mini_batch in range(self.nUpdates):
#
# ~\Documents\SRGP-master\SRGP-master\RECC.py in reset_epoch(self)
#     111             self.dψ_dR = np.zeros((J,self.kern.input_dim))      # gradients of inducing inputs
#     112
# --> 113             dKrr_sparse = self.kern.dK_dX(Z)
#     114             for j in range(0,self.num_inducing):
#     115                 for d in range(0,self.kern.input_dim):
#
# TypeError: wrap() missing 2 required positional arguments: 'X2' and 'dim'

# %%
m2, v2 = modSRGP.predict_diag(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4204\524106214.py in <module>
# ----> 1 m2, v2 = modSRGP.predict_diag(X_test)
#
# NameError: name 'modSRGP' is not defined

# %% [markdown]
# # comparison between batch and SRGP

# %% [markdown]
# ## mean

# %%
plt.figure(figsize=(13,4))
plt.plot(X_test, F_test, 'C1', label='true');
plt.plot(X_train,Y_train, 'r.', label='data');

plt.plot(X_test, m1, 'C2', label='batch')
plt.plot(X_test, m2, 'C0:', label='SRGP')

plt.legend();

# %% [markdown]
# ## variance

# %%
plt.figure(figsize=(13,4))

plt.plot(X_test, m1, 'C2', label='batch')
plt.plot(X_test, m2, 'C0:', label='SRGP')

plt.fill_between(X_test[:,0],m1[:,0]-2*np.sqrt(v1[:,0]),\
                      m1[:,0]+2*np.sqrt(v1[:,0]), alpha=0.1, color='C2', label='batch_95%')

plt.plot(X_test[:,0], m2-2*np.sqrt(v2), 'C0', label='SRGP_95%')
plt.plot(X_test[:,0], m2+2*np.sqrt(v2), 'C0')

plt.legend();

# %% [markdown]
# ## inducing points

# %%
plt.figure(figsize=(13,4))

plt.plot(X_test, m1, 'C2', label='batch')
plt.plot(X_test, m2, 'C0:', label='SVGP')

plt.plot(RR, np.zeros((M,1)), 'C1x', label='prior_IP')
plt.plot(mod.inducing_inputs, mod.posterior.mean, 'C2o', label='batch_IP')
plt.plot(modSRGP.params['R'], modSRGP.m[:,None], 'C0x', markersize=10, label='SRGP_IP')

plt.legend();

# %% [markdown]
# ## convergence of RMSE and bound

# %%
xL = np.arange(nEpochs)
rmseBatch = np.mean( (F_test[:,0]-m1[:,0])**2)**(0.5)

# %%
f, axs = plt.subplots(1, 2, sharex=True, figsize=(15,4))
ax1 = axs[0]
ax2 = axs[1]
# ax3 = axs[2]

ax1.plot( xL, rmseBatch*np.ones(nEpochs)  , 'C2', lw=3, label='batch' );
ax1.plot( xL, modSRGP.STATS[1,:], 'C0', label='SRGP' );
ax1.set_ylim(0.,2);
ax1.legend()
ax1.set_title('RMSE test')
ax1.set_xlabel('# epochs')

ax2.plot( xL, mod._log_marginal_likelihood[0]*np.ones(nEpochs)  , 'C2',  lw=3,label='batch' );
ax2.plot( xL, modSRGP.STATS[0,:] , 'C0', label='SRGP' );
ax2.set_ylim(0,830);
ax2.set_title('bound of LML')
ax2.legend();
ax2.set_xlabel('# epochs');

# %% [markdown]
# ## convergence of hyperparameters

# %%
xOne = np.ones(nEpochs+1)
xL2 = np.arange(nEpochs+1)

# %%
f, axs = plt.subplots(1, 3, sharex=True, figsize=(15,4))
ax1 = axs[0]
ax2 = axs[1]
ax3 = axs[2]

# simga2_0
ax1.plot( xL2, mod.rbf.variance*xOne  , 'C2', lw=3, label='batch' );
ax1.plot( xL2, np.hstack([sig_0_init, modSRGP.STATS_Y[0,:] ])**2 , 'C0', label='SRGP' );
ax1.set_ylim(-0.3, 5);
ax1.set_title('variance '+r'$\sigma_0^2$')
ax1.legend();

# lengthscale
ax2.plot( xL2, mod.rbf.lengthscale[0]*xOne  , 'C2', lw=3, label='batch' );
ax2.plot( xL2, np.hstack([ls_init, modSRGP.STATS_Y[1,:] ]) , 'C0', label='SRGP' );
ax2.set_ylim(0., 1.05);
ax2.set_title('lengthscale '+r'$l$')
ax2.legend();

# lengthscale
ax3.plot( xL2, mod.Gaussian_noise.variance[0]*xOne  , 'C2', lw=3, label='batch' );
ax3.plot( xL2, np.hstack([sig_noise_init, modSRGP.STATS_Y[2,:] ])**2 , 'C0', label='SRGP' );
ax3.set_ylim(0., .2);
ax3.set_title('noise '+r'$\sigma_n^2$')
ax3.legend();

# %%
type(kern)
# Out:
# GPy.kern.src.rbf.RBF

# %%
print(GPy.__version__)
# Out:
# 1.10.0

# %%
# !pip show gpy
# Out:
# Name: GPy
# Version: 1.10.0
# Summary: The Gaussian Process Toolbox
# Home-page: http://sheffieldml.github.com/GPy/
# Author: GPy Authors: https://github.com/SheffieldML/GPy/graphs/contributors
# Author-email: gpy.authors@gmail.com
# License: BSD 3-clause
# Location: c:\users\lomp\appdata\roaming\python\python39\site-packages
# Requires: cython, numpy, paramz, scipy, six
# Required-by:

# %%
# !pip install gpy==1.9.8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gpy==1.9.8
#   Downloading GPy-1.9.8.tar.gz (989 kB)
#      ------------------------------------- 989.5/989.5 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\programdata\anaconda3\lib\site-packages (from gpy==1.9.8) (1.21.5)
# Requirement already satisfied: scipy>=0.16 in c:\programdata\anaconda3\lib\site-packages (from gpy==1.9.8) (1.9.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from gpy==1.9.8) (1.16.0)
# Requirement already satisfied: paramz>=0.9.0 in c:\users\lomp\appdata\roaming\python\python39\site-packages (from gpy==1.9.8) (0.9.5)
# Requirement already satisfied: decorator>=4.0.10 in c:\programdata\anaconda3\lib\site-packages (from paramz>=0.9.0->gpy==1.9.8) (5.1.1)
# Building wheels for collected packages: gpy
#   Building wheel for gpy (setup.py): started
#   Building wheel for gpy (setup.py): finished with status 'error'
#   Running setup.py clean for gpy
# Failed to build gpy
# Installing collected packages: gpy
#   Attempting uninstall: gpy
#     Found existing installation: GPy 1.10.0
#     Uninstalling GPy-1.10.0:
#       Successfully uninstalled GPy-1.10.0
#   Running setup.py install for gpy: started
#   Running setup.py install for gpy: finished with status 'error'
#   Rolling back uninstall of GPy
#   Moving to c:\users\lomp\appdata\roaming\python\python39\site-packages\gpy-1.10.0.dist-info\
#    from C:\Users\lomp\AppData\Roaming\Python\Python39\site-packages\~py-1.10.0.dist-info
#   Moving to c:\users\lomp\appdata\roaming\python\python39\site-packages\gpy\
#    from C:\Users\lomp\AppData\Roaming\Python\Python39\site-packages\~py
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [445 lines of output]
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:771: UserWarning: Usage of dash-separated 'upload-dir' will not be supported in future versions. Please use the underscore name 'upload_dir' instead
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\GPy
#   copying GPy\__init__.py -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\__version__.py -> build\lib.win-amd64-cpython-39\GPy
#   creating build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\gp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\gp_grid.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\mapping.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\model.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\sparse_gp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\sparse_gp_mpi.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\svgp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\symbolic.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\__init__.py -> build\lib.win-amd64-cpython-39\GPy\core
#   creating build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\param.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\parameterized.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\priorizable.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\priors.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\transformations.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\variational.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\__init__.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   creating build\lib.win-amd64-cpython-39\GPy\kern
#   copying GPy\kern\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\add.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\basis_funcs.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\brownian.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\coregionalize.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\eq_ode1.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\eq_ode2.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\grid_kerns.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\independent_outputs.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\integral.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\integral_limits.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\kern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\kernel_slice_operations.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\linear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\mlp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\multidimensional_integral_limits.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\multioutput_kern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_st.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_t.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_UY.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_UYC.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\poly.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\prod.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\rbf.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_brownian.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_linear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_matern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_standard_periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_static.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_stationary.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\spline.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\splitKern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\standard_periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\static.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\symbolic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\symmetric.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\trunclinear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\gaussherm.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\linear_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\rbf_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\rbf_psi_gpucomp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\sslinear_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\ssrbf_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\ssrbf_psi_gpucomp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   creating build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bayesian_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bayesian_gplvm_minibatch.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bcgplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\dpgplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_coregionalized_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_grid_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_heteroscedastic_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_kronecker_gaussian_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_multiout_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_multiout_regression_md.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_offset_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_var_gauss.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gradient_checker.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ibp_lfm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\input_warped_gp.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\mrd.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\one_vs_all_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\one_vs_all_sparse_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_coregionalized_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_minibatch.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_regression_md.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ss_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ss_mrd.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_main.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_model.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_setup.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\tp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\warped_gp.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\__init__.py -> build\lib.win-amd64-cpython-39\GPy\models
#   creating build\lib.win-amd64-cpython-39\GPy\inference
#   copying GPy\inference\__init__.py -> build\lib.win-amd64-cpython-39\GPy\inference
#   creating build\lib.win-amd64-cpython-39\GPy\inference\optimization
#   copying GPy\inference\optimization\stochastics.py -> build\lib.win-amd64-cpython-39\GPy\inference\optimization
#   copying GPy\inference\optimization\__init__.py -> build\lib.win-amd64-cpython-39\GPy\inference\optimization
#   creating build\lib.win-amd64-cpython-39\GPy\inference\mcmc
#   copying GPy\inference\mcmc\hmc.py -> build\lib.win-amd64-cpython-39\GPy\inference\mcmc
#   copying GPy\inference\mcmc\samplers.py -> build\lib.win-amd64-cpython-39\GPy\inference\mcmc
#   copying GPy\inference\mcmc\__init__.py -> build\lib.win-amd64-cpython-39\GPy\inference\mcmc
#   creating build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\dtc.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\exact_gaussian_inference.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\exact_studentt_inference.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\expectation_propagation.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\fitc.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\gaussian_grid_inference.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\grid_posterior.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\inferenceX.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\laplace.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\pep.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\posterior.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\svgp.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\vardtc_md.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\vardtc_svi_multiout.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\vardtc_svi_multiout_miss.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\var_dtc.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\var_dtc_parallel.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\var_gauss.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   copying GPy\inference\latent_function_inference\__init__.py -> build\lib.win-amd64-cpython-39\GPy\inference\latent_function_inference
#   creating build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\bernoulli.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\binomial.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\exponential.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\gamma.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\gaussian.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\likelihood.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\link_functions.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\loggaussian.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\loglogistic.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\mixed_noise.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\multioutput_likelihood.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\poisson.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\student_t.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\weibull.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   copying GPy\likelihoods\__init__.py -> build\lib.win-amd64-cpython-39\GPy\likelihoods
#   creating build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\additive.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\compound.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\constant.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\identity.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\kernel.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\linear.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\mlp.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\mlpext.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\piecewise_linear.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   copying GPy\mappings\__init__.py -> build\lib.win-amd64-cpython-39\GPy\mappings
#   creating build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\classification.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\dimensionality_reduction.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\non_gaussian.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\regression.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\state_space.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   copying GPy\examples\__init__.py -> build\lib.win-amd64-cpython-39\GPy\examples
#   creating build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\cython_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\ep_likelihood_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\examples_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\fitc.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\gpy_kernels_state_space_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\gp_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\grid_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\inference_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\kernel_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\likelihood_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\linalg_test.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\link_function_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\mapping_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\meanfunc_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\minibatch_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\misc_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\model_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\mpi_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\pep_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\pickle_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\plotting_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\prior_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\quadrature_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\rv_transformation_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\serialization_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\state_space_main_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\svgp_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\tp_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\util_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\variational_tests.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   copying GPy\testing\__init__.py -> build\lib.win-amd64-cpython-39\GPy\testing
#   creating build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\block_matrices.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\choleskies.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\classification.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\cluster_with_offset.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\config.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\datasets.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\debug.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\decorators.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\diag.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\functions.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\gpu_init.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\initialization.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\input_warping_functions.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg_gpu.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\ln_diff_erfs.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\misc.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\mocap.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\multioutput.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\netpbmfile.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\normalizer.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\parallel.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\pca.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\quad_integrate.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\squashers.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\subarray_and_sorting.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\univariate_Gaussian.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\warping_functions.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\__init__.py -> build\lib.win-amd64-cpython-39\GPy\util
#   creating build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\abstract_plotting_library.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\Tango.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\data_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\gp_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\inference_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\kernel_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\latent_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\plot_util.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\base_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\defaults.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\img_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\mapping_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\maps.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\plot_definitions.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\priors_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\ssgplvm.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\svig_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\util.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\variational_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\visualize.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\axis_event_controller.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\imshow_controller.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\defaults.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\plot_definitions.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   running egg_info
#   writing GPy.egg-info\PKG-INFO
#   writing dependency_links to GPy.egg-info\dependency_links.txt
#   writing requirements to GPy.egg-info\requires.txt
#   writing top-level names to GPy.egg-info\top_level.txt
#   reading manifest file 'GPy.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'README.rst'
#   adding license file 'LICENSE.txt'
#   adding license file 'AUTHORS.txt'
#   writing manifest file 'GPy.egg-info\SOURCES.txt'
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.kern.src' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.kern.src' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.kern.src' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.kern.src' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.models' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.models' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.models' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.models' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.util' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.util' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.util' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.util' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.kern.src.todo' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.kern.src.todo' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.kern.src.todo' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.kern.src.todo' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   copying GPy\defaults.cfg -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\installation.cfg -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\kern\src\coregionalize_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_utils.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\models\state_space_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\util\choleskies_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\kern\src\coregionalize_cython.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_cython.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_utils.h -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sympy_helpers.h -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src\todo
#   copying GPy\kern\src\todo\odekern1.c -> build\lib.win-amd64-cpython-39\GPy\kern\src\todo
#   copying GPy\models\state_space_cython.c -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\util\choleskies_cython.c -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\data_resources.json -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\football_teams.json -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg_cython.c -> build\lib.win-amd64-cpython-39\GPy\util
#   running build_ext
#   skipping 'GPy/kern/src\stationary_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/util\choleskies_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/util\linalg_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/kern/src\coregionalize_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/models\state_space_cython.c' Cython extension (up-to-date)
#   building 'GPy.kern.src.stationary_cython' extension
#   creating build\temp.win-amd64-cpython-39
#   creating build\temp.win-amd64-cpython-39\Release
#   creating build\temp.win-amd64-cpython-39\Release\GPy
#   creating build\temp.win-amd64-cpython-39\Release\GPy\kern
#   creating build\temp.win-amd64-cpython-39\Release\GPy\kern\src
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include -I. -IC:\ProgramData\Anaconda3\include -IC:\ProgramData\Anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt" /TcGPy/kern/src/stationary_utils.c /Fobuild\temp.win-amd64-cpython-39\Release\GPy/kern/src/stationary_utils.obj -fopenmp -O3
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-fopenmp" wird ignoriert.
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-O3" wird ignoriert.
#   stationary_utils.c
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include -I. -IC:\ProgramData\Anaconda3\include -IC:\ProgramData\Anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt" /TcGPy/kern/src\stationary_cython.c /Fobuild\temp.win-amd64-cpython-39\Release\GPy/kern/src\stationary_cython.obj -fopenmp -O3
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-fopenmp" wird ignoriert.
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-O3" wird ignoriert.
#   stationary_cython.c
#   C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   GPy/kern/src\stationary_cython.c(20142): warning C4996: 'PyEval_InitThreads': deprecated in 3.9
#   GPy/kern/src\stationary_cython.c(20201): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20206): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20221): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20234): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20892): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(20908): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(22618): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(23968): warning C4244: "Initialisierung": Konvertierung von "double" in "float", möglicher Datenverlust
#   GPy/kern/src\stationary_cython.c(23974): warning C4244: "Initialisierung": Konvertierung von "double" in "float", möglicher Datenverlust
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.33.31629\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gpy
#   error: subprocess-exited-with-error
#
#   Running setup.py install for gpy did not run successfully.
#   exit code: 1
#
#   [447 lines of output]
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:771: UserWarning: Usage of dash-separated 'upload-dir' will not be supported in future versions. Please use the underscore name 'upload_dir' instead
#     warnings.warn(
#   running install
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\GPy
#   copying GPy\__init__.py -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\__version__.py -> build\lib.win-amd64-cpython-39\GPy
#   creating build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\gp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\gp_grid.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\mapping.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\model.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\sparse_gp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\sparse_gp_mpi.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\svgp.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\symbolic.py -> build\lib.win-amd64-cpython-39\GPy\core
#   copying GPy\core\__init__.py -> build\lib.win-amd64-cpython-39\GPy\core
#   creating build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\param.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\parameterized.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\priorizable.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\priors.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\transformations.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\variational.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   copying GPy\core\parameterization\__init__.py -> build\lib.win-amd64-cpython-39\GPy\core\parameterization
#   creating build\lib.win-amd64-cpython-39\GPy\kern
#   copying GPy\kern\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\add.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\basis_funcs.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\brownian.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\coregionalize.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\eq_ode1.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\eq_ode2.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\grid_kerns.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\independent_outputs.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\integral.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\integral_limits.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\kern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\kernel_slice_operations.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\linear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\mlp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\multidimensional_integral_limits.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\multioutput_kern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_st.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_t.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_UY.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\ODE_UYC.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\poly.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\prod.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\rbf.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_brownian.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_linear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_matern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_standard_periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_static.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sde_stationary.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\spline.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\splitKern.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\standard_periodic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\static.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\symbolic.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\symmetric.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\trunclinear.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\gaussherm.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\linear_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\rbf_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\rbf_psi_gpucomp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\sslinear_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\ssrbf_psi_comp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\ssrbf_psi_gpucomp.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   copying GPy\kern\src\psi_comp\__init__.py -> build\lib.win-amd64-cpython-39\GPy\kern\src\psi_comp
#   creating build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bayesian_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bayesian_gplvm_minibatch.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\bcgplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\dpgplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_coregionalized_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_grid_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_heteroscedastic_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_kronecker_gaussian_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_multiout_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_multiout_regression_md.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_offset_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gp_var_gauss.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\gradient_checker.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ibp_lfm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\input_warped_gp.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\mrd.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\one_vs_all_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\one_vs_all_sparse_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_classification.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_coregionalized_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_minibatch.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\sparse_gp_regression_md.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ss_gplvm.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\ss_mrd.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_main.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_model.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\state_space_setup.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\tp_regression.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\warped_gp.py -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\models\__init__.py -> build\lib.win-amd64-cpython-39\GPy\models
#   creating build\lib.win-amd64-cpython-39\GPy\inference
# ...
#   copying GPy\util\netpbmfile.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\normalizer.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\parallel.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\pca.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\quad_integrate.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\squashers.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\subarray_and_sorting.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\univariate_Gaussian.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\warping_functions.py -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\__init__.py -> build\lib.win-amd64-cpython-39\GPy\util
#   creating build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\abstract_plotting_library.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\Tango.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   copying GPy\plotting\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\data_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\gp_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\inference_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\kernel_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\latent_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\plot_util.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   copying GPy\plotting\gpy_plot\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\gpy_plot
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\base_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\defaults.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\img_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\mapping_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\maps.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\plot_definitions.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\priors_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\ssgplvm.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\svig_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\util.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\variational_plots.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\visualize.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   copying GPy\plotting\matplot_dep\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\axis_event_controller.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\imshow_controller.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   copying GPy\plotting\matplot_dep\controllers\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\matplot_dep\controllers
#   creating build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\defaults.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\plot_definitions.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   copying GPy\plotting\plotly_dep\__init__.py -> build\lib.win-amd64-cpython-39\GPy\plotting\plotly_dep
#   running egg_info
#   writing GPy.egg-info\PKG-INFO
#   writing dependency_links to GPy.egg-info\dependency_links.txt
#   writing requirements to GPy.egg-info\requires.txt
#   writing top-level names to GPy.egg-info\top_level.txt
#   reading manifest file 'GPy.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'README.rst'
#   adding license file 'LICENSE.txt'
#   adding license file 'AUTHORS.txt'
#   writing manifest file 'GPy.egg-info\SOURCES.txt'
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.kern.src' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.kern.src' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.kern.src' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.kern.src' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.models' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.models' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.models' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.models' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.util' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.util' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.util' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.util' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'GPy.kern.src.todo' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'GPy.kern.src.todo' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'GPy.kern.src.todo' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'GPy.kern.src.todo' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   copying GPy\defaults.cfg -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\installation.cfg -> build\lib.win-amd64-cpython-39\GPy
#   copying GPy\kern\src\coregionalize_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_utils.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\models\state_space_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\util\choleskies_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg_cython.pyx -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\kern\src\coregionalize_cython.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_cython.c -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\stationary_utils.h -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   copying GPy\kern\src\sympy_helpers.h -> build\lib.win-amd64-cpython-39\GPy\kern\src
#   creating build\lib.win-amd64-cpython-39\GPy\kern\src\todo
#   copying GPy\kern\src\todo\odekern1.c -> build\lib.win-amd64-cpython-39\GPy\kern\src\todo
#   copying GPy\models\state_space_cython.c -> build\lib.win-amd64-cpython-39\GPy\models
#   copying GPy\util\choleskies_cython.c -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\data_resources.json -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\football_teams.json -> build\lib.win-amd64-cpython-39\GPy\util
#   copying GPy\util\linalg_cython.c -> build\lib.win-amd64-cpython-39\GPy\util
#   running build_ext
#   skipping 'GPy/kern/src\stationary_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/util\choleskies_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/util\linalg_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/kern/src\coregionalize_cython.c' Cython extension (up-to-date)
#   skipping 'GPy/models\state_space_cython.c' Cython extension (up-to-date)
#   building 'GPy.kern.src.stationary_cython' extension
#   creating build\temp.win-amd64-cpython-39
#   creating build\temp.win-amd64-cpython-39\Release
#   creating build\temp.win-amd64-cpython-39\Release\GPy
#   creating build\temp.win-amd64-cpython-39\Release\GPy\kern
#   creating build\temp.win-amd64-cpython-39\Release\GPy\kern\src
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include -I. -IC:\ProgramData\Anaconda3\include -IC:\ProgramData\Anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt" /TcGPy/kern/src/stationary_utils.c /Fobuild\temp.win-amd64-cpython-39\Release\GPy/kern/src/stationary_utils.obj -fopenmp -O3
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-fopenmp" wird ignoriert.
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-O3" wird ignoriert.
#   stationary_utils.c
#   "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include -I. -IC:\ProgramData\Anaconda3\include -IC:\ProgramData\Anaconda3\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.33.31629\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt" /TcGPy/kern/src\stationary_cython.c /Fobuild\temp.win-amd64-cpython-39\Release\GPy/kern/src\stationary_cython.obj -fopenmp -O3
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-fopenmp" wird ignoriert.
#   cl : Befehlszeile warning D9002 : Unbekannte Option "-O3" wird ignoriert.
#   stationary_cython.c
#   C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   GPy/kern/src\stationary_cython.c(20142): warning C4996: 'PyEval_InitThreads': deprecated in 3.9
#   GPy/kern/src\stationary_cython.c(20201): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20206): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20221): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20234): error C2039: "tp_print" ist kein Member von "_typeobject".
#   C:\ProgramData\Anaconda3\include\cpython/object.h(193): note: Siehe Deklaration von "_typeobject"
#   GPy/kern/src\stationary_cython.c(20892): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(20908): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(22618): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#   GPy/kern/src\stationary_cython.c(23968): warning C4244: "Initialisierung": Konvertierung von "double" in "float", möglicher Datenverlust
#   GPy/kern/src\stationary_cython.c(23974): warning C4244: "Initialisierung": Konvertierung von "double" in "float", möglicher Datenverlust
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.33.31629\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# gpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import paramz.caching
