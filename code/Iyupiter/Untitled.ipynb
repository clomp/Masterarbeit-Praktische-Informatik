# %%
import gpflow
# Out:
# 2022-11-14 22:56:40.184335: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import gpflow
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/gpflow/__init__.py:17
#       1 # Copyright 2016-2020 The GPflow Contributors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      14
#      15 # flake8: noqa
# ---> 17 from . import (
#      18     conditionals,
#      19     config,
#      20     covariances,
#      21     expectations,
#      22     experimental,
# ...

# %%
import
